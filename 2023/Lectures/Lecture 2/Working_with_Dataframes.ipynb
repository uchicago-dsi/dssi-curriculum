# %% [markdown]
# <center>
#
# # Working with Dataframes
# <center>
# <img src="https://raw.githubusercontent.com/amandakube/Data118LectureImages/main/UChicago_DSI.png" alt="UC-DSI" width="300" height="100">
# </center>
# <br><br>
#
# <img src="https://raw.githubusercontent.com/amandakube/Data118LectureImages/main/DSSI.png" width="800">
# </center>

# %% [markdown]
# # Handling Dataframes

# %% [markdown]
# In this lecture, we're going to talk about some ways to handle and work with dataframes, which includes basic selection and deletion of columns, renaming columns, and other topics. Then, we'll go a bit into subsetting data using various selection methods. Finally, we talk about some methods for dataframes that will be useful for data organization, manipulation and analysis. First, let's import pandas and numpy.

# %%
import pandas as pd
import numpy as np

# %%
sales = pd.read_csv('../Sample-Data/train.csv')
sales.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Ship Mode Customer ID
# 0       1  CA-2017-152156    8/11/17    11/11/17          2    CG-12520  \
# 1       2  CA-2017-152156    8/11/17    11/11/17          2    CG-12520
# 2       3  CA-2017-138688    12/6/17  16/06/2017          2    DV-13045
#
#      Customer Name    Segment        Country         City       State
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky  \
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Postal Code Region       Product ID         Category Sub-Category
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases  \
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62

# %% [markdown]
# This is a dataset of sales from a retail store over 4 years. At a quick glance, we can see the type of data collected. We have some IDs in the form of alphanumerical data, some dates, names, locations, etc.
#
# In getting acquainted with our data, we may want to quickly know how many entries there are and how many attributes are measured per entry:

# %%
print(sales.shape)
# Out:
# (9804, 18)

# %% [markdown]
# Recall that dataframes are made of concatanated series in the form of columns. To extract one column from a dataframe, we call for the dataframe and then close the name of the column (as a string) in single square brackets or double square brackets:

# %%
sales['Segment']
# Out:
# 0        Consumer
# 1        Consumer
# 2       Corporate
# 3        Consumer
# 4        Consumer
#           ...
# 9799    Corporate
# 9800    Corporate
# 9801    Corporate
# 9802    Corporate
# 9803    Corporate
# Name: Segment, Length: 9804, dtype: object

# %%
sales[['Segment']]
# Out:
#         Segment
# 0      Consumer
# 1      Consumer
# 2     Corporate
# 3      Consumer
# 4      Consumer
# ...         ...
# 9799  Corporate
# 9800  Corporate
# 9801  Corporate
# 9802  Corporate
# 9803  Corporate
#
# [9804 rows x 1 columns]

# %% [markdown]
# What do notice about the difference in extracting a column with single square brackets versus double square brackets?
#
# Notice that using single square brackets returns a series, while the use of double square brackets return a one-column dataframe. This is important, as it can dictate how the output can be used, as well as what functions and methods can be used on it.
#
# For example, if we wanted to get the first item of the `Segment` column, we could use `sales['Segment'][0]` with a series, but not with a dataframe:

# %%
sales['Segment'][0]
# Out:
# 'Consumer'

# %%
sales[['Segment']][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [115], in <cell line: 1>()
# ----> 1 sales[['Segment']][0]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 0

# %% [markdown]
# However, if you wanted to select multiple columns at once, that can be done with a dataframe, but not a series:

# %%
sales[['Segment', 'Ship Mode']]
# Out:
#         Segment  Ship Mode
# 0      Consumer          2
# 1      Consumer          2
# 2     Corporate          2
# 3      Consumer          3
# 4      Consumer          3
# ...         ...        ...
# 9799  Corporate          3
# 9800  Corporate          3
# 9801  Corporate          3
# 9802  Corporate          3
# 9803  Corporate          3
#
# [9804 rows x 2 columns]

# %%
sales['Segment', 'Ship Mode']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Segment', 'Ship Mode')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 sales['Segment', 'Ship Mode']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: ('Segment', 'Ship Mode')

# %% [markdown]
# It is also useful to rename columns in a dataframe using the `.rename()` method. Calling this method on a dataframe, you can easily rename a column by passing a dictionary with the keys being the current column name and the values being the desired column name:

# %%
sales = sales.rename(columns={'Postal Code':'Zip Code', 'Ship Mode':'Shipping Method'})
sales.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 0       1  CA-2017-152156    8/11/17    11/11/17                2    CG-12520  \
# 1       2  CA-2017-152156    8/11/17    11/11/17                2    CG-12520
# 2       3  CA-2017-138688    12/6/17  16/06/2017                2    DV-13045
#
#      Customer Name    Segment        Country         City       State
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky  \
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Zip Code Region       Product ID         Category Sub-Category
# 0   42420.0  South  FUR-BO-10001798        Furniture    Bookcases  \
# 1   42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2   90036.0   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62

# %% [markdown]
# New columns can be added to dataframes as well. If you wish to add a column based on other columns that already exist in the dataframe, you can perform operations on the columns and assign them to the new desired column. Here, we make a new column called `Full Location` that combines data from the `City` and `State` columns, separated by a comma:

# %%
sales['Full Location'] = sales['City'] + ', ' + sales['State']
sales.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 0       1  CA-2017-152156    8/11/17    11/11/17                2    CG-12520  \
# 1       2  CA-2017-152156    8/11/17    11/11/17                2    CG-12520
# 2       3  CA-2017-138688    12/6/17  16/06/2017                2    DV-13045
#
#      Customer Name    Segment        Country         City       State
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky  \
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Zip Code Region       Product ID         Category Sub-Category
# 0   42420.0  South  FUR-BO-10001798        Furniture    Bookcases  \
# 1   42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2   90036.0   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96  \
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62
#
#              Full Location
# 0      Henderson, Kentucky
# 1      Henderson, Kentucky
# 2  Los Angeles, California

# %% [markdown]
# If desired, you can also create an empty column:

# %%
sales['Empty'] = ""
sales.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 0       1  CA-2017-152156    8/11/17    11/11/17                2    CG-12520  \
# 1       2  CA-2017-152156    8/11/17    11/11/17                2    CG-12520
# 2       3  CA-2017-138688    12/6/17  16/06/2017                2    DV-13045
#
#      Customer Name    Segment        Country         City       State
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky  \
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Zip Code Region       Product ID         Category Sub-Category
# 0   42420.0  South  FUR-BO-10001798        Furniture    Bookcases  \
# 1   42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2   90036.0   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96  \
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62
#
#              Full Location Empty
# 0      Henderson, Kentucky
# 1      Henderson, Kentucky
# 2  Los Angeles, California

# %% [markdown]
# There may be times where you want to delete columns. This can be accomplished using the `.drop()` method. When you call this method on a dataframe, you can pass a single column name or a list of column names to the `columns` parameter. The `inplace=True` parameter updates the dataframe.

# %%
sales.drop(columns=['Country', 'Empty'], inplace=True)
sales.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 0       1  CA-2017-152156    8/11/17    11/11/17                2    CG-12520  \
# 1       2  CA-2017-152156    8/11/17    11/11/17                2    CG-12520
# 2       3  CA-2017-138688    12/6/17  16/06/2017                2    DV-13045
#
#      Customer Name    Segment         City       State  Zip Code Region
# 0      Claire Gute   Consumer    Henderson    Kentucky   42420.0  South  \
# 1      Claire Gute   Consumer    Henderson    Kentucky   42420.0  South
# 2  Darrin Van Huff  Corporate  Los Angeles  California   90036.0   West
#
#         Product ID         Category Sub-Category
# 0  FUR-BO-10001798        Furniture    Bookcases  \
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96  \
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62
#
#              Full Location
# 0      Henderson, Kentucky
# 1      Henderson, Kentucky
# 2  Los Angeles, California

# %% [markdown]
# Notice that we utilized two ways of updating dataframes using these methods. One way was to use the method on the dataframe and reassign the output of that to the name of the dataframe (as we did when using the `.rename()` method. The other way was by specifying the `inplace` parameter as `True` (as we did with the `.drop()` method). Both of these ways are fine, but be mindful that not all methods and functions have an `inplace` parameter. Therefore, it's always a good idea to refer to the documentation of a function or method to understand how it can be used.

# %% [markdown]
# <code style="background:yellow;color:black">Question/activity: TBD</code>

# %% [markdown]
# # Subsetting data in dataframes

# %% [markdown]
# Being able to parse and subset data intentionally is important for downstream data analysis. When consecutive rows of data need to be extracted, dataframes can be sliced similar to lists and arrays. To extract the first 50 rows of `sales` we could slice the dataframe as follows:

# %%
top50 = sales[0:50]
print('Number of rows in top50:', len(top50))
top50.head(3)
# Out:
# Number of rows in top50: 50
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 0       1  CA-2017-152156    8/11/17    11/11/17                2    CG-12520  \
# 1       2  CA-2017-152156    8/11/17    11/11/17                2    CG-12520
# 2       3  CA-2017-138688    12/6/17  16/06/2017                2    DV-13045
#
#      Customer Name    Segment         City       State  Zip Code Region
# 0      Claire Gute   Consumer    Henderson    Kentucky   42420.0  South  \
# 1      Claire Gute   Consumer    Henderson    Kentucky   42420.0  South
# 2  Darrin Van Huff  Corporate  Los Angeles  California   90036.0   West
#
#         Product ID         Category Sub-Category
# 0  FUR-BO-10001798        Furniture    Bookcases  \
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96  \
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62
#
#              Full Location
# 0      Henderson, Kentucky
# 1      Henderson, Kentucky
# 2  Los Angeles, California

# %% [markdown]
# Likewise we can extract intervals of rows using double colons:

# %%
even_rows = sales[0::2]
print('Selecting every other column gives us a dataframe of', len(even_rows), 'rows.')

even_rows.head(3)
# Out:
# Selecting every other column gives us a dataframe of 4902 rows.
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 0       1  CA-2017-152156    8/11/17    11/11/17                2    CG-12520  \
# 2       3  CA-2017-138688    12/6/17  16/06/2017                2    DV-13045
# 4       5  US-2016-108966   11/10/16  18/10/2016                3    SO-20335
#
#      Customer Name    Segment             City       State  Zip Code Region
# 0      Claire Gute   Consumer        Henderson    Kentucky   42420.0  South  \
# 2  Darrin Van Huff  Corporate      Los Angeles  California   90036.0   West
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida   33311.0  South
#
#         Product ID         Category Sub-Category
# 0  FUR-BO-10001798        Furniture    Bookcases  \
# 2  OFF-LA-10000240  Office Supplies       Labels
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name    Sales
# 0                  Bush Somerset Collection Bookcase  261.960  \
# 2  Self-Adhesive Address Labels for Typewriters b...   14.620
# 4                     Eldon Fold 'N Roll Cart System   22.368
#
#               Full Location
# 0       Henderson, Kentucky
# 2   Los Angeles, California
# 4  Fort Lauderdale, Florida

# %% [markdown]
# To exact all rows and a specific column, we can use the `.iloc[]` method. The `.iloc[]` method uses integer-location based indexing for selection of rows and columns by position. To select all rows and the `Ship Date` column (which has an index of 3), we can type the following code:

# %%
sales.iloc[:, 3]
# Out:
# 0         11/11/17
# 1         11/11/17
# 2       16/06/2017
# 3       18/10/2016
# 4       18/10/2016
#            ...
# 9799    28/05/2017
# 9800    17/01/2016
# 9801    17/01/2016
# 9802    17/01/2016
# 9803    17/01/2016
# Name: Ship Date, Length: 9804, dtype: object

# %% [markdown]
# Vice versa, we can select the data corresponding to all columns of the fourth row (which has an index of 3).

# %%
sales.iloc[3, :]
# Out:
# Row ID                                                         4
# Order ID                                          US-2016-108966
# Order Date                                              11/10/16
# Ship Date                                             18/10/2016
# Shipping Method                                                3
# Customer ID                                             SO-20335
# Customer Name                                     Sean O'Donnell
# Segment                                                 Consumer
# City                                             Fort Lauderdale
# State                                                    Florida
# Zip Code                                                 33311.0
# Region                                                     South
# Product ID                                       FUR-TA-10000577
# Category                                               Furniture
# Sub-Category                                              Tables
# Product Name       Bretford CR4500 Series Slim Rectangular Table
# Sales                                                   957.5775
# Full Location                           Fort Lauderdale, Florida
# Name: 3, dtype: object

# %% [markdown]
# Using `.iloc[]` we can specifically select cells of a dataframe by inputting its row and column index values:

# %%
sales.iloc[234, 9]
# Out:
# 'Florida'

# %% [markdown]
# Similar to slicing, we can also select specific indexes or a a range of consecutive indexes:

# %%
sales.iloc[0:500, [3,6,12]]
# Out:
#       Ship Date    Customer Name       Product ID
# 0      11/11/17      Claire Gute  FUR-BO-10001798
# 1      11/11/17      Claire Gute  FUR-CH-10000454
# 2    16/06/2017  Darrin Van Huff  OFF-LA-10000240
# 3    18/10/2016   Sean O'Donnell  FUR-TA-10000577
# 4    18/10/2016   Sean O'Donnell  OFF-ST-10000760
# ..          ...              ...              ...
# 495  31/12/2016    Maribeth Dona  OFF-EN-10001434
# 496  31/07/2017     Sanjit Chand  OFF-BI-10002498
# 497  31/07/2017     Sanjit Chand  FUR-FU-10004864
# 498  31/07/2017     Sanjit Chand  FUR-CH-10002602
# 499  31/07/2017     Sanjit Chand  FUR-FU-10000073
#
# [500 rows x 3 columns]

# %%
#What do you think this does? Discuss with your neighbor

rows = np.arange(45,107, step = 5)

sales.iloc[rows, 13:]
# Out:
#             Category Sub-Category
# 45   Office Supplies      Binders  \
# 50   Office Supplies       Labels
# 55   Office Supplies      Storage
# 60   Office Supplies      Binders
# 65         Furniture  Furnishings
# 70   Office Supplies      Binders
# 75   Office Supplies      Binders
# 80   Office Supplies      Binders
# 85         Furniture       Chairs
# 90        Technology       Phones
# 95   Office Supplies      Binders
# 100       Technology  Accessories
# 105  Office Supplies      Binders
#
#                                           Product Name    Sales
# 45   Wilson Jones Leather-Like Binders with DublLoc...   17.460  \
# 50                                           Avery 485   75.180
# 55                     Home/Office Personal File Carts  208.560
# 60                               Plastic Binding Combs   48.480
# 65                         Luxo Economy Swing Arm Lamp   79.760
# 70   Avery Binding System Hidden Tab Executive Styl...    4.616
# 75                                     Economy Binders    1.248
# 80     Avery Heavy-Duty EZD  Binder With Locking Rings   16.740
# 85                    Novimex Swivel Fabric Task Chair  301.960
# 90                                  Panasonic Kx-TS550   73.584
# 95   Flexible Leather- Look Classic Collection Ring...    5.682
# 100  SanDisk Ultra 64 GB MicroSDHC Class 10 Memory ...   95.976
# 105  Avery Trapezoid Ring Binder, 3" Capacity, Blac...   36.882
#
#                 Full Location
# 45           Eagan, Minnesota
# 50        New Albany, Indiana
# 55             Troy, New York
# 60             Troy, New York
# 65    Los Angeles, California
# 70    New York City, New York
# 75             Houston, Texas
# 80           Decatur, Alabama
# 85   Columbia, South Carolina
# 90    Los Angeles, California
# 95           Portland, Oregon
# 100         Chicago, Illinois
# 105          Aurora, Colorado

# %%
#What do you think this does? Discuss with your neighbor

sales.iloc[2999:3872:100, 4::3]
# Out:
#       Ship Mode      Segment           State       Product ID
# 2999          3     Consumer    Pennsylvania  TEC-MA-10004521  \
# 3099          3     Consumer        New York  OFF-BI-10000829
# 3199          3    Corporate    Pennsylvania  OFF-AR-10003183
# 3299          3     Consumer    Pennsylvania  OFF-BI-10003656
# 3399          3    Corporate        Kentucky  OFF-PA-10004359
# 3499          3     Consumer         Alabama  TEC-AC-10000420
# 3599          2     Consumer    Pennsylvania  TEC-PH-10002549
# 3699          2  Home Office        New York  TEC-AC-10004114
# 3799          1    Corporate  North Carolina  TEC-PH-10002483
#
#                                            Product Name
# 2999                Epson Perfection V600 Photo Scanner
# 3099                            Avery Non-Stick Binders
# 3199       Avery Fluorescent Highlighter Four-Color Set
# 3299        Fellowes PB200 Plastic Comb Binding Machine
# 3399                 Multicolor Computer Printout Paper
# 3499  Logitech G500s Laser Gaming Mouse with Adjusta...
# 3599               Polycom SoundPoint IP 450 VoIP phone
# 3699           KeyTronic 6101 Series - Keyboard - Black
# 3799                                    Motorola Moto X

# %% [markdown]
# Another way to extract data from dataframes is using the `.loc[]` method. The `.loc[]` method utilizes labels or boolean arrays to select data. While specifying the indices of a list of rows you wish to select, you can utilize the name of a column to extract data of interest, as shown below:

# %%
sales.loc[[22,485,1008], "Category"]
# Out:
# 22      Office Supplies
# 485           Furniture
# 1008    Office Supplies
# Name: Category, dtype: object

# %% [markdown]
# Moreover, you can select multiple columns by passing a list into the `.loc[]` method:

# %%
sales.loc[[22,485,1008], ["Category", "Sub-Category", "Shipping Method"]]
# Out:
#              Category Sub-Category  Shipping Method
# 22    Office Supplies   Appliances                3
# 485         Furniture    Bookcases                1
# 1008  Office Supplies        Paper                3

# %% [markdown]
# The `.loc[]` method is a really powerful selection method that can be used to extract data based on conditions. Here, we select all rows where the `Region` column equates to `West`:

# %%
west = sales.loc[(sales['Region'] == 'West')]
west.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 2       3  CA-2017-138688    12/6/17  16/06/2017                2    DV-13045  \
# 5       6  CA-2015-115812     9/6/15  14/06/2015                3    BH-11710
# 6       7  CA-2015-115812     9/6/15  14/06/2015                3    BH-11710
#
#      Customer Name    Segment         City       State  Zip Code Region
# 2  Darrin Van Huff  Corporate  Los Angeles  California   90036.0   West  \
# 5  Brosina Hoffman   Consumer  Los Angeles  California   90032.0   West
# 6  Brosina Hoffman   Consumer  Los Angeles  California   90032.0   West
#
#         Product ID         Category Sub-Category
# 2  OFF-LA-10000240  Office Supplies       Labels  \
# 5  FUR-FU-10001487        Furniture  Furnishings
# 6  OFF-AR-10002833  Office Supplies          Art
#
#                                         Product Name  Sales
# 2  Self-Adhesive Address Labels for Typewriters b...  14.62  \
# 5  Eldon Expressions Wood and Plastic Desk Access...  48.86
# 6                                         Newell 322   7.28
#
#              Full Location
# 2  Los Angeles, California
# 5  Los Angeles, California
# 6  Los Angeles, California

# %% [markdown]
# We can also compound conditions using bitwise operators. We can select rows that meet one of multiple conditions by using the `|` operator:

# %%
w_florida = sales.loc[(sales['Region'] == 'West') | (sales['State'] == 'Florida')] #mention bitwise operators earlier?
w_florida.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 2       3  CA-2017-138688    12/6/17  16/06/2017                2    DV-13045  \
# 3       4  US-2016-108966   11/10/16  18/10/2016                3    SO-20335
# 4       5  US-2016-108966   11/10/16  18/10/2016                3    SO-20335
#
#      Customer Name    Segment             City       State  Zip Code Region
# 2  Darrin Van Huff  Corporate      Los Angeles  California   90036.0   West  \
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida   33311.0  South
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida   33311.0  South
#
#         Product ID         Category Sub-Category
# 2  OFF-LA-10000240  Office Supplies       Labels  \
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200  \
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#               Full Location
# 2   Los Angeles, California
# 3  Fort Lauderdale, Florida
# 4  Fort Lauderdale, Florida

# %% [markdown]
# If we want rows that meet <u>all</u> of our conditions of interests, we can use the `&` operator:

# %%
ny_low = sales.loc[(sales['State'] == 'New York') & (sales['Sales'] < 100)]
ny_low.head(3)
# Out:
#     Row ID        Order ID  Order Date   Ship Date  Shipping Method
# 53      54  CA-2017-105816    11/12/17  17/12/2017                3  \
# 56      57  CA-2017-111682  17/06/2017  18/06/2017                1
# 58      59  CA-2017-111682  17/06/2017  18/06/2017                1
#
#    Customer ID    Customer Name    Segment           City     State  Zip Code
# 53    JM-15265   Janet Molinari  Corporate  New York City  New York   10024.0  \
# 56    TB-21055  Ted Butterfield   Consumer           Troy  New York   12180.0
# 58    TB-21055  Ted Butterfield   Consumer           Troy  New York   12180.0
#
#    Region       Product ID         Category Sub-Category
# 53   East  OFF-FA-10000304  Office Supplies    Fasteners  \
# 56   East  OFF-PA-10001569  Office Supplies        Paper
# 58   East  OFF-PA-10000587  Office Supplies        Paper
#
#                               Product Name  Sales            Full Location
# 53                      Advantus Push Pins  15.26  New York City, New York
# 56                               Xerox 232  32.40           Troy, New York
# 58  Array Parchment Paper, Assorted Colors  14.56           Troy, New York

# %% [markdown]
# As shown before, we don't have to return all rows of the dataframe when selecting based on condition. We can return only the rows of interest by passing the names of these rows as a list into the `.loc[]` method:

# %%
dvh = sales.loc[(sales['Customer Name'] == 'Darrin Van Huff'), ['Order Date', 'Customer Name', 'Category']]
dvh
# Out:
#       Order Date    Customer Name         Category
# 2        12/6/17  Darrin Van Huff  Office Supplies
# 2976     4/12/18  Darrin Van Huff        Furniture
# 5300  23/09/2017  Darrin Van Huff  Office Supplies
# 5301  23/09/2017  Darrin Van Huff  Office Supplies
# 5619  30/06/2018  Darrin Van Huff        Furniture
# 7347    11/12/18  Darrin Van Huff        Furniture
# 7348    11/12/18  Darrin Van Huff       Technology
# 7349    11/12/18  Darrin Van Huff  Office Supplies
# 7350    11/12/18  Darrin Van Huff        Furniture

# %% [markdown]
# Using a combination of index-based and label-based location, the `.loc[]` method also allows us to select specific cell of interest. By doing so, we can change data in our dataframe as needed:

# %%
sales.loc[0, ['Ship Date']]
# Out:
# Ship Date    11/11/17
# Name: 0, dtype: object

# %%
sales.loc[0, ['Ship Date']] = '11/13/2017'
sales.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 0       1  CA-2017-152156    8/11/17  11/13/2017                2    CG-12520  \
# 1       2  CA-2017-152156    8/11/17    11/11/17                2    CG-12520
# 2       3  CA-2017-138688    12/6/17  16/06/2017                2    DV-13045
#
#      Customer Name    Segment         City       State  Zip Code Region
# 0      Claire Gute   Consumer    Henderson    Kentucky   42420.0  South  \
# 1      Claire Gute   Consumer    Henderson    Kentucky   42420.0  South
# 2  Darrin Van Huff  Corporate  Los Angeles  California   90036.0   West
#
#         Product ID         Category Sub-Category
# 0  FUR-BO-10001798        Furniture    Bookcases  \
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96  \
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62
#
#              Full Location
# 0      Henderson, Kentucky
# 1      Henderson, Kentucky
# 2  Los Angeles, California

# %% [markdown]
# Finally, we can use `.loc[]` to insert rows in specific positions. If we want to insert a row between index 9798 and 9799, can set an index at some number in between (i.e. 9798.5) and add data using a dictionary. The key of the dictionary corresponds to the name of the column and the value corresponds to the data added in that column for the row:

# %%
sales.loc[9802.5] = {'Order ID': 'KB-2023-1849274', 'Order Date':'05/22/2023', "Customer Name": "Kewon Bell", 
                     "Region":"Central", "City":"Chicago", "State":"Illinois"}
sales.tail()
# Out:
#         Row ID         Order ID  Order Date   Ship Date  Shipping Method
# 9800.0  9797.0   CA-2016-128608     12/1/16  17/01/2016              3.0  \
# 9801.0  9798.0   CA-2016-128608     12/1/16  17/01/2016              3.0
# 9802.0  9799.0   CA-2016-128608     12/1/16  17/01/2016              3.0
# 9803.0  9800.0   CA-2016-128608     12/1/16  17/01/2016              3.0
# 9802.5     NaN  KB-2023-1849274  05/22/2023         NaN              NaN
#
#        Customer ID     Customer Name    Segment     City     State  Zip Code
# 9800.0    CS-12490  Cindy Schnelling  Corporate   Toledo      Ohio   43615.0  \
# 9801.0    CS-12490  Cindy Schnelling  Corporate   Toledo      Ohio   43615.0
# 9802.0    CS-12490  Cindy Schnelling  Corporate   Toledo      Ohio   43615.0
# 9803.0    CS-12490  Cindy Schnelling  Corporate   Toledo      Ohio   43615.0
# 9802.5         NaN        Kewon Bell        NaN  Chicago  Illinois       NaN
#
#          Region       Product ID         Category Sub-Category
# 9800.0     East  OFF-AR-10001374  Office Supplies          Art  \
# 9801.0     East  TEC-PH-10004977       Technology       Phones
# 9802.0     East  TEC-PH-10000912       Technology       Phones
# 9803.0     East  TEC-AC-10000487       Technology  Accessories
# 9802.5  Central              NaN              NaN          NaN
#
#                                     Product Name    Sales Full Location
# 9800.0  BIC Brite Liner Highlighters, Chisel Tip   10.368  Toledo, Ohio
# 9801.0                               GE 30524EE4  235.188  Toledo, Ohio
# 9802.0  Anker 24W Portable Micro USB Car Charger   26.376  Toledo, Ohio
# 9803.0       SanDisk Cruzer 4 GB USB Flash Drive   10.384  Toledo, Ohio
# 9802.5                                       NaN      NaN           NaN

# %% [markdown]
# Notice that for the columns that we did not list, NaN was used. NaN stands for "Not a Number", which is used as a placeholder since we did not have any data for these columns.
#
# Now that we have our data added to the end of our dataframe, we can sort the indexes by using the `.sort_index()` method. When we call this method on our dataframe, we can set the `ascending` parameter equal to `False` to have our indexes go from largest to smallest. We can then set `inplace` equal to `True` so that it updates the dataframe without reassignment:

# %%
sales.sort_index(ascending=False, inplace=True)
sales.head(3)
# Out:
#         Row ID         Order ID  Order Date   Ship Date  Shipping Method
# 9803.0  9800.0   CA-2016-128608     12/1/16  17/01/2016              3.0  \
# 9802.5     NaN  KB-2023-1849274  05/22/2023         NaN              NaN
# 9802.0  9799.0   CA-2016-128608     12/1/16  17/01/2016              3.0
#
#        Customer ID     Customer Name    Segment     City     State  Zip Code
# 9803.0    CS-12490  Cindy Schnelling  Corporate   Toledo      Ohio   43615.0  \
# 9802.5         NaN        Kewon Bell        NaN  Chicago  Illinois       NaN
# 9802.0    CS-12490  Cindy Schnelling  Corporate   Toledo      Ohio   43615.0
#
#          Region       Product ID    Category Sub-Category
# 9803.0     East  TEC-AC-10000487  Technology  Accessories  \
# 9802.5  Central              NaN         NaN          NaN
# 9802.0     East  TEC-PH-10000912  Technology       Phones
#
#                                     Product Name   Sales Full Location
# 9803.0       SanDisk Cruzer 4 GB USB Flash Drive  10.384  Toledo, Ohio
# 9802.5                                       NaN     NaN           NaN
# 9802.0  Anker 24W Portable Micro USB Car Charger  26.376  Toledo, Ohio

# %% [markdown]
# The new row has been place in between the 9803 index and 9802 index. This is the desired location that we wanted, however, we do not want an index as a float. To fix this, we can simply reset our indexes using `.reset_index()`:

# %%
sales.reset_index(drop=True, inplace=True)
sales.head(3)
# Out:
#    Row ID         Order ID  Order Date   Ship Date  Shipping Method
# 0  9800.0   CA-2016-128608     12/1/16  17/01/2016              3.0  \
# 1     NaN  KB-2023-1849274  05/22/2023         NaN              NaN
# 2  9799.0   CA-2016-128608     12/1/16  17/01/2016              3.0
#
#   Customer ID     Customer Name    Segment     City     State  Zip Code
# 0    CS-12490  Cindy Schnelling  Corporate   Toledo      Ohio   43615.0  \
# 1         NaN        Kewon Bell        NaN  Chicago  Illinois       NaN
# 2    CS-12490  Cindy Schnelling  Corporate   Toledo      Ohio   43615.0
#
#     Region       Product ID    Category Sub-Category
# 0     East  TEC-AC-10000487  Technology  Accessories  \
# 1  Central              NaN         NaN          NaN
# 2     East  TEC-PH-10000912  Technology       Phones
#
#                                Product Name   Sales Full Location
# 0       SanDisk Cruzer 4 GB USB Flash Drive  10.384  Toledo, Ohio
# 1                                       NaN     NaN           NaN
# 2  Anker 24W Portable Micro USB Car Charger  26.376  Toledo, Ohio

# %% [markdown]
# Our dataframe has now been sorted and reset. All of the rows at the end are now at the beginning.
#
# But say we made a mistake and we wanted to remove that row again, we could use the `.drop()` method again, but this time, use the `index` parameter and set it to the index of the row we want to remove. To update the dataframe you can use reassignment or set `inplace=True`:

# %%
sales.drop(index=1, inplace=True)
sales.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 0  9800.0  CA-2016-128608    12/1/16  17/01/2016              3.0    CS-12490  \
# 2  9799.0  CA-2016-128608    12/1/16  17/01/2016              3.0    CS-12490
# 3  9798.0  CA-2016-128608    12/1/16  17/01/2016              3.0    CS-12490
#
#       Customer Name    Segment    City State  Zip Code Region
# 0  Cindy Schnelling  Corporate  Toledo  Ohio   43615.0   East  \
# 2  Cindy Schnelling  Corporate  Toledo  Ohio   43615.0   East
# 3  Cindy Schnelling  Corporate  Toledo  Ohio   43615.0   East
#
#         Product ID    Category Sub-Category
# 0  TEC-AC-10000487  Technology  Accessories  \
# 2  TEC-PH-10000912  Technology       Phones
# 3  TEC-PH-10004977  Technology       Phones
#
#                                Product Name    Sales Full Location
# 0       SanDisk Cruzer 4 GB USB Flash Drive   10.384  Toledo, Ohio
# 2  Anker 24W Portable Micro USB Car Charger   26.376  Toledo, Ohio
# 3                               GE 30524EE4  235.188  Toledo, Ohio

# %% [markdown]
# So now we have the row we want removed, but I would still like to fix our `Row ID` column to make them integers again. We can do this using a method called `.astype()`. This method can be used to change the data type of a dataframe or series. We can use it to change the `Row ID` column from floats to integers:

# %%
sales['Row ID'] = sales['Row ID'].astype(int)
sales.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date  Shipping Method Customer ID
# 0    9800  CA-2016-128608    12/1/16  17/01/2016              3.0    CS-12490  \
# 2    9799  CA-2016-128608    12/1/16  17/01/2016              3.0    CS-12490
# 3    9798  CA-2016-128608    12/1/16  17/01/2016              3.0    CS-12490
#
#       Customer Name    Segment    City State  Zip Code Region
# 0  Cindy Schnelling  Corporate  Toledo  Ohio   43615.0   East  \
# 2  Cindy Schnelling  Corporate  Toledo  Ohio   43615.0   East
# 3  Cindy Schnelling  Corporate  Toledo  Ohio   43615.0   East
#
#         Product ID    Category Sub-Category
# 0  TEC-AC-10000487  Technology  Accessories  \
# 2  TEC-PH-10000912  Technology       Phones
# 3  TEC-PH-10004977  Technology       Phones
#
#                                Product Name    Sales Full Location
# 0       SanDisk Cruzer 4 GB USB Flash Drive   10.384  Toledo, Ohio
# 2  Anker 24W Portable Micro USB Car Charger   26.376  Toledo, Ohio
# 3                               GE 30524EE4  235.188  Toledo, Ohio

# %% [markdown]
# Finally, we can set the indexes of our dataframe to any column within the dataframe. Since we just set our `Row ID` back to integers, we can use this column to set our indices. We will do this using the `.set_index()` method:

# %%
sales.set_index('Row ID', inplace=True)
sales.tail(3)
# Out:
#               Order ID Order Date   Ship Date  Shipping Method Customer ID
# Row ID
# 3       CA-2017-138688    12/6/17  16/06/2017              2.0    DV-13045  \
# 2       CA-2017-152156    8/11/17    11/11/17              2.0    CG-12520
# 1       CA-2017-152156    8/11/17  11/13/2017              2.0    CG-12520
#
#           Customer Name    Segment         City       State  Zip Code Region
# Row ID
# 3       Darrin Van Huff  Corporate  Los Angeles  California   90036.0   West  \
# 2           Claire Gute   Consumer    Henderson    Kentucky   42420.0  South
# 1           Claire Gute   Consumer    Henderson    Kentucky   42420.0  South
#
#              Product ID         Category Sub-Category
# Row ID
# 3       OFF-LA-10000240  Office Supplies       Labels  \
# 2       FUR-CH-10000454        Furniture       Chairs
# 1       FUR-BO-10001798        Furniture    Bookcases
#
#                                              Product Name   Sales
# Row ID
# 3       Self-Adhesive Address Labels for Typewriters b...   14.62  \
# 2       Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 1                       Bush Somerset Collection Bookcase  261.96
#
#                   Full Location
# Row ID
# 3       Los Angeles, California
# 2           Henderson, Kentucky
# 1           Henderson, Kentucky

# %% [markdown]
# <code style="background:yellow;color:black">activity

# %% [markdown]
# # Organizing, manipulating, analyzing data in dataframes

# %% [markdown]
# There are many functions and methods that can assist with organizing, manipulating, and analyzing data in dataframes. We will discuss several important ones to remember.
#
# The first method we will discuss is the `.sort_values()` method. This is a useful method for looking at trends or sequential values in a dataset. The `.sort_values()` method has an `ascending` parameter, which is set to `True` by default. It also has an `inplace` parameter, which is set to `False` by default:

# %%
sales.sort_values('City', inplace= True) #multiple sorting like in excel?
sales.head(3)
# Out:
#               Order ID  Order Date   Ship Date  Shipping Method Customer ID
# Row ID
# 9261    CA-2018-167976    11/11/18  14/11/2018              2.0    JL-15505  \
# 6990    CA-2018-165099    11/12/18  13/12/2018              1.0    DK-13375
# 454     CA-2018-147277  20/10/2018  24/10/2018              3.0    EB-13705
#
#           Customer Name    Segment      City         State  Zip Code   Region
# Row ID
# 9261    Jeremy Lonsdale   Consumer  Aberdeen  South Dakota   57401.0  Central  \
# 6990        Dennis Kane   Consumer   Abilene         Texas   79605.0  Central
# 454          Ed Braxton  Corporate     Akron          Ohio   44312.0     East
#
#              Product ID         Category Sub-Category
# Row ID
# 9261    OFF-SU-10004661  Office Supplies     Supplies  \
# 6990    OFF-AP-10001634  Office Supplies   Appliances
# 454     FUR-TA-10001539        Furniture       Tables
#
#                                         Product Name    Sales
# Row ID
# 9261                   Acme Titanium Bonded Scissors   25.500  \
# 6990    Hoover Commercial Lightweight Upright Vacuum    1.392
# 454         Chromcraft Rectangular Conference Tables  284.364
#
#                  Full Location
# Row ID
# 9261    Aberdeen, South Dakota
# 6990            Abilene, Texas
# 454                Akron, Ohio

# %% [markdown]
# Another useful method is the
# `.value_counts()` method. This method can be used on a series to count the number of occurences for each unique value in the series. Let's use this method to determine how many shipments were shipped to each region:

# %%
sales['Region'].value_counts()
# Out:
# Region
# West       3141
# East       2788
# Central    2277
# South      1598
# Name: count, dtype: int64

# %% [markdown]
# There are a number of statistical and summative methods that can be used on dataframes as well. For example, the `.min()` and `.max()` methods can be used on a a dataframe or a column within a dataframe to determine the minimum and maximum values, respectively. The `.describe` method returns multiple useful summary statistics:

# %%
sales['Sales'].min()
# Out:
# 0.444

# %%
sales['Sales'].max()
# Out:
# 22638.48

# %%
sales['Sales'].describe()
# Out:
# count     9804.000000
# mean       230.685164
# std        626.537954
# min          0.444000
# 25%         17.246000
# 50%         54.432000
# 75%        210.568000
# max      22638.480000
# Name: Sales, dtype: float64

# %% [markdown]
# Here's a short list of methods that can be used to determine summative information and/or statistics:
#
# `.min()` - determines the minimum value in a dataframe/series
#
# `.max()` - determines the maximum value in a dataframe/series
#
# `.mean()` - determines the mean value of a dataframe/series
#
# `.median()` - determines the median value in a dataframe/series
#
# `.sum()` - determines the sum of the values in a dataframe/series
#
# `.mode()` - determines the mode of a dataframe/series
#
# `.nlargest()` - determines the largest *n* items in a series. (Default = 5)
#
# `.nsmallest()` - determines the smallest *n* items in a series. (Default = 5)
#
# `.count()` - counts all non-null items in a dataframe/series
#
# `.value_counts` - counts the number of times an item occurs in a dataframe/series
#
# `.nunique()` - counts the number of unique items in a dataframe/series
#
# `.unique()` - lists all of the unique items in a dataframe/series
#
# `.describe` - generates descriptive statistics of a dataframe column, including those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding null values (NaN).

# %% [markdown]
# Sometimes when working with data, especially data generated by human input, we encounter errors within the data. Once useful tool that can be used to find mistakes is the `.duplicated()` method. This method shows duplicated rows within a dataframe, like so:

# %%
sales[sales.duplicated()]
# Out:
#               Order ID  Order Date   Ship Date  Shipping Method Customer ID
# Row ID
# 4842    CA-2017-136049  23/12/2017  28/12/2017              3.0    NM-18520  \
# 3407    US-2015-150119  23/04/2015  27/04/2015              3.0    LB-16795
# 7276    CA-2016-144519  13/11/2016  17/11/2016              3.0    AW-10930
# 8607    CA-2018-162936  18/08/2018  22/08/2018              3.0    CM-12160
# 4761    CA-2015-121573     3/11/15     7/11/15              3.0    SG-20605
#
#             Customer Name      Segment           City          State
# Row ID
# 4842         Neoma Murray     Consumer  Bowling Green           Ohio  \
# 3407       Laurel Beltran  Home Office       Columbus           Ohio
# 7276      Arthur Wiediger  Home Office         Helena        Montana
# 8607    Charles McCrossin     Consumer    New Bedford  Massachusetts
# 4761     Speros Goranitis     Consumer  New York City       New York
#
#         Zip Code Region       Product ID         Category Sub-Category
# Row ID
# 4842     43402.0   East  OFF-BI-10001267  Office Supplies      Binders  \
# 3407     43229.0   East  FUR-CH-10002965        Furniture       Chairs
# 7276     59601.0   West  FUR-FU-10000794        Furniture  Furnishings
# 8607      2740.0   East  TEC-AC-10003614       Technology  Accessories
# 4761     10009.0   East  OFF-BI-10003712  Office Supplies      Binders
#
#                                              Product Name    Sales
# Row ID
# 4842    Universal Recycled Hanging Pressboard Report B...    5.553  \
# 3407    Global Leather Highback Executive Chair with P...  281.372
# 7276        Eldon Stackable Tray, Side-Load, Legal, Smoke   63.980
# 8607    Verbatim 25 GB 6x Blu-ray Single Layer Recorda...   23.180
# 4761    Acco Pressboard Covers with Storage Hooks, 14 ...    7.856
#
#                      Full Location
# Row ID
# 4842           Bowling Green, Ohio
# 3407                Columbus, Ohio
# 7276               Helena, Montana
# 8607    New Bedford, Massachusetts
# 4761       New York City, New York

# %% [markdown]
# When `.duplicated()` is called on a dataframe, another dataframe containing the rows of the duplicated entries is returned to us. We can easily get rid of these duplicated rows by calling `.drop_duplicates()` on the dataframe:

# %%
print(sales.shape)
sales = sales.drop_duplicates()
print(sales.shape)
# Out:
# (9804, 17)
# (9799, 17)

# %% [markdown]
# We say that prior to dropping the duplicates, `sales` had 9804 rows. After dropping the duplicates, there are now 9799 rows, 5 less than before. This is the number of rows that were determined to be duplicated in `sales`, as shown above.
#
# We can also correct typos observed in dataframes. Say for example, we had a customer listed in our dataframe as Eric Hoffmann. We can extract all the rows pertaining to this customer:

# %%
sales.loc[(sales['Customer Name']) == 'Eric Hoffmann'].head(3)
# Out:
#               Order ID  Order Date   Ship Date  Shipping Method Customer ID
# Row ID
# 6088    CA-2016-114048  14/12/2016  18/12/2016              3.0    EH-13945  \
# 1110    US-2017-110156  19/11/2017  24/11/2017              3.0    EH-13945
# 1112    US-2017-110156  19/11/2017  24/11/2017              3.0    EH-13945
#
#         Customer Name   Segment        City       State  Zip Code   Region
# Row ID
# 6088    Eric Hoffmann  Consumer  Costa Mesa  California   92627.0     West  \
# 1110    Eric Hoffmann  Consumer     Houston       Texas   77041.0  Central
# 1112    Eric Hoffmann  Consumer     Houston       Texas   77041.0  Central
#
#              Product ID         Category Sub-Category
# Row ID
# 6088    FUR-FU-10004351        Furniture  Furnishings  \
# 1110    OFF-EN-10003798  Office Supplies    Envelopes
# 1112    OFF-PA-10004735  Office Supplies        Paper
#
#                                              Product Name   Sales
# Row ID
# 6088                           Staple-based wall hangings  29.220  \
# 1110    Recycled Interoffice Envelopes with Re-Use-A-S...  40.968
# 1112                                           Xerox 1905  10.368
#
#                  Full Location
# Row ID
# 6088    Costa Mesa, California
# 1110            Houston, Texas
# 1112            Houston, Texas

# %% [markdown]
# Say an extra 'n' was accidentally added to Eric's last name. We can correct this typo in all of these cells by using the `.replace()` method. When using the `.replace()` method, we can call the current mispelling into the `to_replace` parameter. We can then call the correct spelling into the `value` parameter. The `inplace` parameter will update our dataframe in real time.
#
# If try to extract rows with the original spelling, we get an empty dataframe returned to us:

# %%
sales.replace(to_replace='Eric Hoffmann', value='Eric Hoffman', inplace=True)
sales.loc[(sales['Customer Name']) == 'Eric Hoffmann'].head(3)
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Ship Date, Shipping Method, Customer ID, Customer Name, Segment, City, State, Zip Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Full Location]
# Index: []

# %% [markdown]
# If we use the new spelling, we can see that the name has been updated:

# %%
sales.loc[(sales['Customer Name']) == 'Eric Hoffman'].head(3)
# Out:
#               Order ID  Order Date   Ship Date  Shipping Method Customer ID
# Row ID
# 6088    CA-2016-114048  14/12/2016  18/12/2016              3.0    EH-13945  \
# 1110    US-2017-110156  19/11/2017  24/11/2017              3.0    EH-13945
# 1112    US-2017-110156  19/11/2017  24/11/2017              3.0    EH-13945
#
#        Customer Name   Segment        City       State  Zip Code   Region
# Row ID
# 6088    Eric Hoffman  Consumer  Costa Mesa  California   92627.0     West  \
# 1110    Eric Hoffman  Consumer     Houston       Texas   77041.0  Central
# 1112    Eric Hoffman  Consumer     Houston       Texas   77041.0  Central
#
#              Product ID         Category Sub-Category
# Row ID
# 6088    FUR-FU-10004351        Furniture  Furnishings  \
# 1110    OFF-EN-10003798  Office Supplies    Envelopes
# 1112    OFF-PA-10004735  Office Supplies        Paper
#
#                                              Product Name   Sales
# Row ID
# 6088                           Staple-based wall hangings  29.220  \
# 1110    Recycled Interoffice Envelopes with Re-Use-A-S...  40.968
# 1112                                           Xerox 1905  10.368
#
#                  Full Location
# Row ID
# 6088    Costa Mesa, California
# 1110            Houston, Texas
# 1112            Houston, Texas

# %% [markdown]
# We can also apply string methods to columns in a dataframe and update the column through variable assignment:

# %%
sales['State'] = sales['State'].str.upper()
sales.head(3)
# Out:
#               Order ID  Order Date   Ship Date  Shipping Method Customer ID
# Row ID
# 9261    CA-2018-167976    11/11/18  14/11/2018              2.0    JL-15505  \
# 6990    CA-2018-165099    11/12/18  13/12/2018              1.0    DK-13375
# 454     CA-2018-147277  20/10/2018  24/10/2018              3.0    EB-13705
#
#           Customer Name    Segment      City         State  Zip Code   Region
# Row ID
# 9261    Jeremy Lonsdale   Consumer  Aberdeen  SOUTH DAKOTA   57401.0  Central  \
# 6990        Dennis Kane   Consumer   Abilene         TEXAS   79605.0  Central
# 454          Ed Braxton  Corporate     Akron          OHIO   44312.0     East
#
#              Product ID         Category Sub-Category
# Row ID
# 9261    OFF-SU-10004661  Office Supplies     Supplies  \
# 6990    OFF-AP-10001634  Office Supplies   Appliances
# 454     FUR-TA-10001539        Furniture       Tables
#
#                                         Product Name    Sales
# Row ID
# 9261                   Acme Titanium Bonded Scissors   25.500  \
# 6990    Hoover Commercial Lightweight Upright Vacuum    1.392
# 454         Chromcraft Rectangular Conference Tables  284.364
#
#                  Full Location
# Row ID
# 9261    Aberdeen, South Dakota
# 6990            Abilene, Texas
# 454                Akron, Ohio

# %% [markdown]
# Another useful method is the `.map()` method. The `.map()` method substitutes values from a series, dictionary, or function based on current values in the dataframe. Using this method, we can map the values in the `Shipping Method` column to their corresponding string values like so:

# %%
new_vals = {0: 'Same Day', 1: 'First Class', 2:'Second Class', 3:'Standard Class'}

sales['Shipping Method'] = sales['Shipping Method'].map(new_vals)
sales.head()
# Out:
#               Order ID  Order Date   Ship Date Shipping Method Customer ID
# Row ID
# 9261    CA-2018-167976    11/11/18  14/11/2018             NaN    JL-15505  \
# 6990    CA-2018-165099    11/12/18  13/12/2018             NaN    DK-13375
# 454     CA-2018-147277  20/10/2018  24/10/2018             NaN    EB-13705
# 4324    US-2016-147662  14/02/2016  19/02/2016             NaN    KB-16315
# 4325    US-2016-147662  14/02/2016  19/02/2016             NaN    KB-16315
#
#           Customer Name    Segment      City         State  Zip Code   Region
# Row ID
# 9261    Jeremy Lonsdale   Consumer  Aberdeen  SOUTH DAKOTA   57401.0  Central  \
# 6990        Dennis Kane   Consumer   Abilene         TEXAS   79605.0  Central
# 454          Ed Braxton  Corporate     Akron          OHIO   44312.0     East
# 4324         Karl Braun   Consumer     Akron          OHIO   44312.0     East
# 4325         Karl Braun   Consumer     Akron          OHIO   44312.0     East
#
#              Product ID         Category Sub-Category
# Row ID
# 9261    OFF-SU-10004661  Office Supplies     Supplies  \
# 6990    OFF-AP-10001634  Office Supplies   Appliances
# 454     FUR-TA-10001539        Furniture       Tables
# 4324    OFF-BI-10002160  Office Supplies      Binders
# 4325    OFF-AR-10004999  Office Supplies          Art
#
#                                         Product Name    Sales
# Row ID
# 9261                   Acme Titanium Bonded Scissors   25.500  \
# 6990    Hoover Commercial Lightweight Upright Vacuum    1.392
# 454         Chromcraft Rectangular Conference Tables  284.364
# 4324                       Acco Hanging Data Binders    2.286
# 4325                                      Newell 315   14.352
#
#                  Full Location       Ship Mode
# Row ID
# 9261    Aberdeen, South Dakota    Second Class
# 6990            Abilene, Texas     First Class
# 454                Akron, Ohio  Standard Class
# 4324               Akron, Ohio  Standard Class
# 4325               Akron, Ohio  Standard Class

# %% [markdown]
# Applying values and functions en masse to datasets is a quick and easy way to analyze and modify data. The `.applymap()` method is great for this because uses a function and applies it to an entire dataframe. Say we wanted to convert all the data in sales to string data, we would do:

# %%
strings = sales.applymap(str)
strings.head(3)
# Out:
#               Order ID  Order Date   Ship Date Shipping Method Customer ID
# Row ID
# 9261    CA-2018-167976    11/11/18  14/11/2018             nan    JL-15505  \
# 6990    CA-2018-165099    11/12/18  13/12/2018             nan    DK-13375
# 454     CA-2018-147277  20/10/2018  24/10/2018             nan    EB-13705
#
#           Customer Name    Segment      City         State Zip Code   Region
# Row ID
# 9261    Jeremy Lonsdale   Consumer  Aberdeen  SOUTH DAKOTA  57401.0  Central  \
# 6990        Dennis Kane   Consumer   Abilene         TEXAS  79605.0  Central
# 454          Ed Braxton  Corporate     Akron          OHIO  44312.0     East
#
#              Product ID         Category Sub-Category
# Row ID
# 9261    OFF-SU-10004661  Office Supplies     Supplies  \
# 6990    OFF-AP-10001634  Office Supplies   Appliances
# 454     FUR-TA-10001539        Furniture       Tables
#
#                                         Product Name    Sales
# Row ID
# 9261                   Acme Titanium Bonded Scissors     25.5  \
# 6990    Hoover Commercial Lightweight Upright Vacuum    1.392
# 454         Chromcraft Rectangular Conference Tables  284.364
#
#                  Full Location       Ship Mode
# Row ID
# 9261    Aberdeen, South Dakota    Second Class
# 6990            Abilene, Texas     First Class
# 454                Akron, Ohio  Standard Class

# %% [markdown]
# By eye, `strings` looks the same as `sales`, but upon closer investigation, we can see that the numbers have been converted to strings:

# %%
strings['Zip Code'][5] #Picking a random number from the Zip Code column
# Out:
# '33311.0'

# %%
print(type(strings['Zip Code'][5]))
# Out:
# <class 'str'>

# %% [markdown]
# The `.apply()` method is also great for applying a function to a dataframe across an axis (i.e. across rows or across columns). For example, if we wanted to count the strings in each state for each row, we could apply the `len()` function:

# %%
sales['State'].apply(len)
# Out:
# Row ID
# 9261    12
# 6990     5
# 454      4
# 4324     4
# 4325     4
#         ..
# 3348    10
# 8088     7
# 7282     7
# 7280     7
# 4823     7
# Name: State, Length: 9799, dtype: int64

# %% [markdown]
# You will see other applications of `.apply()` when learning how to make user-defined functions.

# %% [markdown]
# <code style="background:yellow;color:black">Activity: TBD
