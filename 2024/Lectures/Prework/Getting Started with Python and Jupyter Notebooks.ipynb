# %% [markdown]
# <center>
#
# # Welcome To Juypter Notebooks!
#
# <center>
# <img src="https://raw.githubusercontent.com/amandakube/Data118LectureImages/main/UChicago_DSI.png" alt="UC-DSI" width="300" height="100">
# </center>

# %% [markdown]
# Jupyter Notebooks provide a way to integrate code input, output, and explanatory text all in one place.
#
# Let's do a walk-through of the notebook environment. Note: Your Jupyter Notebooks set-up may look slightly different than what we show here, but will have all of the same functionality.
#
# Jupyter notebooks will open in your default browser. You usually will not be able to open a notebook the way you open other files on your computer. Instead you will need to do it either through something like Anaconda Navigator or from the terminal. (This was covered in more detail in your installation instructions.)
#
# When we open a notebook, the notebook runs out of what is called a **kernel**. A kernel is an instance or a *session* in which you may type and run Python code in a shell.
#
# ## Opening and renaming Jupyter Notebooks
# On the side bar of your notebook, you may see a number of files housed within the *current working directory*. Depending on your set-up these may also be in a different browser window. The current working directory is the folder where you are currently located, which in this case, will be the folder that contains this notebook.
#
# If you have any other notebooks within your current working directory, you can open them by simply clicking the name of the notebook. If you navigate to `File > New` at the top left corner, you will see the option to create a new notebook. When making a new notebook, we want to click on `New > Python 3 (ipykernel)` because we are working in Python.
#
# <img src="https://raw.githubusercontent.com/campbelle1/CAN2023/d49ec1f3a1f3f05bc54c4e195cc3f114b83e9337/(2)Open_NewNb.gif" width="1000" align="center">
#
# > *Opening a new Jupyter Notebook*
#
# Doing so will create an untitled notebook in a new window. If you go to `File > Rename Notebook...`, you can rename this notebook to whatever you like. You can also right-click on the tab of the notebook and rename it from there. If you ever decide that you want to create a new Python notebook, this is one way to do it.
#
#
# ****

# %% [markdown]
# ## Code and markdown cells
#
#
# There are two types of cells that we will be focusing on: **code** cells and **markdown** cells.
#
# Code cells are cells in which we can write Python code that can be executed to perform a certain task and/or give a certain output. Code cells can also contain *comments*, which are demarcated by a hashtag ( # ). Comments are not executed by the computer, but can be useful for a human reader in understanding the code.
#
# Markdown cells are used to make human-readable text and graphics (like this cell that you're currently reading). Markdown cells can also utilize some HTML code elements for modifying text and pictures (For an example, double click this cell and see below). When executed, markdown code renders all text and graphics in a readable form. You can change the type of cell by navigating to the dropdown menu in the toolbar and selecting either `Code` or `Markdown`.
#
# <img src="https://raw.githubusercontent.com/campbelle1/CAN2023/main/(2)Code_Markdown.gif" width="1000" align="center">
#
# > *Changing between a code and markdown cell*
#
# <u>Examples of each cell type are given below:</u>

# %%
# This is a code cell.
# Code cells execute written code that is not commented away by a hashtag
# When you run a line that is commented away, the line is skipped over.
# Nothing will happen if you run this cell.

# %% [markdown]
# ### This is a markdown cell (with a H3 header).
#
# > You can find *text*, **links**, <u>photos</u>, etc. in markdown cells.
#
# - For more information on markdown features, refer to the **Markdown in Jupyter Notebook Tutorial** by Datacamp <a href="https://www.datacamp.com/tutorial/markdown-in-jupyter-notebook">here</a>.
#
# ---

# %% [markdown]
# ## Creating, deleting, and moving cells
#
# Adding and deleting cells are important functionalities within Jupyter notebooks. To make a new cell, simply click the *add* icon on the left side of the toolbar. A new cell will be added immediately after the current selected cell. If you wish to add a new cell above or below the currently selected cell, you can utilize the *insert above* and *insert below* icons located within the selected cell.
#
#
# To delete cells, first select the cell(s) that you want to delete. Then, click the *delete* icon located within the cell itself. Alternatively, you can utilize the *cut* icon located on the left side of the toolbar. If you want to place that cell somewhere else within your notebook, you can select where you want the cell to go and then hit the *paste* icon in the toolbar. This will paste the cell that you cut immediately after the cell that you selected.
#
# Lastly, you can copy a cell using the *copy* icon in the toolbar and paste that cell in a desired location within the notebook, as previously described.
#
# To change the order of cells within the notebook, utilize the *up* and *down* arrows within the the cell itself. You can move multiple <u>consecutive</u> notebooks simultaneously throughout the notebook this way.
#
# When changing cells and content, it is a good habit to save your notebook often. This can be done using the *save* icon located on the far-left side of the toolbar.
#
# <img src="https://raw.githubusercontent.com/campbelle1/CAN2023/main/Screenshot%202023-06-04%20at%201.46.34%20PM.png" width="1000" align="center">
#
# > *Icons for adding, deleting, and moving cells*

# %% [markdown]
# ****
# ## Running cells
#
# To run a selected cell, you can utilize several options. In the `Run` tab in the menu bar, you can choose to `Run Selected Cells`, `Run Selected Cells and Insert Below`, `Run Selected Cells and Do not Advance`, `Run All`, or `Restart Kernel and Run All`.
#
# - The `Run Selected Cells` option will simply run a selected cell(s) show the output, and advance to the next cell. This option can also be done by clicking the *run cell* option in the toolbar. If a subsequent cell does not exist, a new cell is created.
#
# - The `Run Selected Cells and Insert Below` option will run the selected cell(s), show the output, and then insert a new cell.
#
# - The `Run Selected Cells and Do not Advance` option will run the selected cell(s) and show the output, but will not select the subsequent cell.
#
# - The `Run All` option will run all cells in the notebook in order, show the output, and advance to the next cell. This option can also be done by clicking the *run cell* option in the toolbar. If a subsequent cell does not exist, a new cell is created.
#
# - The `Restart Kernel and Run All` option will first restart the kernel which essentially restarts your session. You will lose all data, variables, and other objects from the session and cell execution counts will start over at 0. Then it will run all cells like above.
#
# The keyboard shortcuts for these options are displayed next to them in the `Run` tab. It will be extremely useful for you to learn at least one of these shortcuts, particularly the `Run Selected Cells` shortcut: Shift+Enter.
#
# <img src="https://raw.githubusercontent.com/campbelle1/CAN2023/main/(2)Run_cells.gif" width="1000" align="center">
#
# > *Running cells*
#
# ****

# %% [markdown]
# ## Executing cells and outputs
#
# To the left of a code cell, you will see `[ ]:`. Within the brackets, you will see a number when a cell that has been successfully executed. In notebooks, cells can be run out of order, so this number on the side indicates the order in which the cell was executed in the kernel.
#
# When the brackets are blue (and/or there is an 'In' before the brackets), the corresponding cell is referred to as the input cell, and when the brackets are red (and/or there is an 'Out' before the brackets), the corresponding cell is referred to as the output cell. When a cell has `[*]:` next to it, it means that the cell is currently running or is queued to run.
#
# <img src="https://raw.githubusercontent.com/campbelle1/CAN2023/a73238e7e88b6087245e75bc87649364b7c51434/Run_Code_Markdown.gif" width="1000" align="center">
#
# > *Cell outputs*
#
#
# There may come a point when a cell takes a long time to run and/or you may want to stop a cell from running. To do this, you can go to `Kernel > Interrupt Kernel` or click the *interrupt kernel* icon in the toolbar and this will stop the kernel from executing the cell that is currently running. There will also be times when you may want to start the kernel over with a "clean slate" in order to erase all the defined variables and objects in the session. To do this, you can go to `Kernel > Restart Kernel...`. Doing so will erase all data, variables, and other objects from the session, but it will keep the output from the previous session. If you wish to clear out all the objects <u>and</u> outputs from the previous session, you can go to `Kernel > Restart Kernel and Clear All Outputs`. Sometimes this is best to do when you are developing code and you want to make sure that you are getting all the expected/desired outputs.
#
#
# <img src="https://raw.githubusercontent.com/campbelle1/CAN2023/8bb70cb95dd28c7e3c71b6f589cdd63539d858bb/kernel-toolz.png" width="1000" align="center">
#
# > *Icons for running cells, interrupting the kernel, and restarting the kernel*
#
# ****

# %% [markdown]
# # Python Basics
#
# Now that we understand the Jupyter Notebook environment, let's become acquainted with coding in Python. We will start off with simple arithmetic operators, as this is very similar to what we see in our math classes. All of the following information can also be found in [Chapter 3](https://ds1.datascience.uchicago.edu/03/1/Operations.html) of The University of Chicago's Introduction to Data Science Textbook (currently under revision). If you have time and are looking for additional content, Chapters 4, 6, and 7 would also be useful, but I welcome you to look through any (existing) chapters of interest before class.
#
#
# ## Arithmetic Operators
#
# In Python, you can perform mathematical operations, as you could do in a calculator. As such, the same rules around math (i.e. order of operations) follow. To perform these operations, you can use the operators listed below:
#
# <br>
#
# <div>
# <img src="https://raw.githubusercontent.com/campbelle1/Introduction-to-Data-Science/38ca37054d01d81ad5007be4473edbf94f8d6ab0/Week%201/arithmetic%20operators.png" width="600"/>
# </div>

# %%
#Example of a multiplication expression

5.5 * 22

# %%
#Example of a subtraction expression

106 - 88

# %%
#Following order of operations, what will the below expression give us?

5 - 2 * 3 + 12

# %%
#Following order of operations, what will the below expression give us?

(3**2 + 6) * 6

# %%
#Spacing operators between numbers and operators is fine, but Python is very strict about following syntax rules

3 ** 2

# %%
#Not following the rules will give you an error

3 * * 2

# %% [markdown]
# ## Variable Assignments & Call Expressions
#
# In Python, there are various types of *objects*, which can be used to store data. To easily access this data, we can give objects names through *variable assignment*. Using variable assignment, we can store values and access them for later use. This is akin to variables we see in math, like $x = 2 * 3 + 5$.
#
# We can use variable assignment to assign a value and use it in another expression. Variables have to start with a letter and can't have any spaces in them. We use a single equal sign (`=`) to assign variables.

# %%
num_1 = 56 * 42

# %% [markdown]
# Here we defined `num_1`, but when we ran the cell, nothing happened. That is because an variable assignment does not warrant any output. If we want to see our newly assigned variable, we will have to *call* for it by typing it in our cell and executing the cell:

# %%
num_1

# %% [markdown]
# Using `num_1`, let's create a new variable called `num_2`

# %%
num_2 = num_1 // 7
num_2

# %%
num_3

# %% [markdown]
# Sometimes when we are running code, we may skip around or even forget to assign a variable, in which case we get the above error. In general, errors tell you want is wrong and can even give a hint on how to fix it. Let's define `num_3` to resolve this error.

# %%
num_3 = num_2 % 36
num_3

# %% [markdown]
# Note it is important to understand when to expect an output and when not to. Making a **statement**, such as assigning a variable or importing a library does not give an output. The computer will simply perform the desired task behind the scenes. **Call expressions**, like when we called for `num_1`, `num_2`, and `num_3`, asks the computer to return the named variable, which prints to the console as an output.
#
# Below, we will learn how to call for functions and import other functions from libraries.

# %% [markdown]
# ## Calling Functions & Importing Libraries
#
# ### Calling for functions
#
# Python comes with a lot of built-in functions. A *function* is a set of code that performs a task. To use a function, you must invoke it through a call expression. Just like how we called for a variable above, we can call for functions by typing the function name followed by parentheses. It will look something like:
#     `function(...)`
#
# Functions have <u>*arguments*</u> which are used as inputs. Functions take these inputs and perform task(s). This may result in an output or it may be "behind the scenes" (like when we first defined `num_1`).
#
# One of the most basic functions you will use in Python is the `print()` function. As the name suggests, the `print()` function prints an output to the console:

# %%
print(5+2)

# %% [markdown]
# Later, you will see more use of the `print()` function. For now, it's important to understand that the `print()` function allows us to print more than one thing to the console. Calling a variable to print its output only works if that variable is the very last line in the cell. To see the output of multiple variables, we need to use `print()`.

# %%
a = 9
b = 11

a
b

# %%
a = 9
b = 11

print(a)
print(b)

# %% [markdown]
# Another important function to know in Python is the `help()` function. The `help()` function requires another function as input. In exchange, it provides documentation on how to use that function:

# %%
help(print)

# %% [markdown]
# The `help()` function is useful because it allows you to see how a function is used, what arguments are required, and other useful information.

# %% [markdown]
# ### Importing libraries
#
# Sometimes we may need to use things that are not built-in to Python. In these cases, we need to use the `import` statement to import the libraries that we need. Let's import the `math` library, which contains additional math functions that we can use:

# %%
import math

# %% [markdown]
# Now that we've imported the `math` library, we have a bunch of other functions that we can access. When we need to use a function from a library, we call the function by first calling the library from which the function derives. Then, we add the function name like so: `library_name.function_name()`.

# %%
math.sqrt(4)

# %% [markdown]
# Above we used the `sqrt()` function in the `math` library to find the square root of the input argument, which was 4.
#
#
# Functions can also have multiple arguments. The `math` library also has a function called `pow()` which accepts two arguments. The first argument represents the base number. The second argument represents the exponent to which the base is raised. With these input arguments, the `math.pow()` function returns the answer:

# %%
math.pow(2,3)

# %% [markdown]
# For a full list of all the functions you can use from the `math` library, refer to the online documentation:
# https://docs.python.org/3/library/math.html
#
# Other important libraries we will use in this course include the `pandas` library, `numpy` library, and `matplotlib` library, which each have their own documentation as well.

# %% [markdown]
# Lastly, functions can be used as input for another function, creating what is called a *nested function*. **What do you think the below nested function is doing? What do you think the output will be?**

# %%
math.sqrt(math.pow(3,4))

# %% [markdown]
# ## ✏ <mark style="background-color: Thistle">Exercise</mark>

# %% [markdown]
# From the `math` library we can use the number pi by calling `math.pi`:

# %%
math.pi

# %% [markdown]
# Q1. How can we write an expression in Python for determining the area of a circle for a given radius?
#
# Q2. How can we find this area for a circle with a radius of 5? Assign this value to a variable called `radius` and use it in the expression in Q1. Print the result.

# %%
# Write your answers here

# %% [markdown]
# # Data Types
#
# Python has built-in data types that are used to build data structures, as input for various functions, and many other applications. The major data types we will discuss throughout this program are booleans, strings, integers, and floats.

# %% [markdown]
# ## Integers
#
# Integers are a numeric data type that consist of whole numbers. Some examples of integers are -14, 9, 20, 0, -7.
#
# Integers can be used to do fast mathematical calculations.
#
# Certain mathematical functions only give integer outputs. For example, the `math.floor()` and `math.ceil()` functions can take an expression or variable and rounds it down or up, respectively, to the nearest whole number.

# %%
math.floor(7/3)

# %%
math.ceil(4.82)

# %% [markdown]
# ## Floats
#
# Floats (aka floating point numbers) are a numeric data type that consists of a whole number followed by decimal places. Some examples of floating point numbers are 2.1, -9.453, 3.14159, 0.0
#
# Floats can hold up to 15 significant figures after a decimal point and are used for more accurate calculations.
#
# The `round()` function allows for a float variable to be rounded to a given decimal place:

# %%
pi = math.pi
round(pi, 2)

# %% [markdown]
# Floats and integers can be interchanged using the `float()` and `int()` functions.

# %%
print(float(-2))
print(int(pi))

# %% [markdown]
# Another useful function to know as it pertains to data types is the `type()` function. The type function allows you to determine what data type a variable is.

# %%
type(54//9)

# %% [markdown]
# ## Booleans
#
# Booleans are a binary data type consisting of `True` or `False` values. These values equate to the numeric values 1 and 0, respectively. They are often used in comparison operators and control statements (to be discussed in a future lecture).

# %%
2 + 3 < 6 - 4

# %% [markdown]
# You can use the `bool()` function to turn a variable into a boolean. Anything of value will be `True`, anything equal to 0 will be `False`.

# %%
bool(0)

# %% [markdown]
# # Comparison & Logical Operators
#
# ### Comparison Operators
# Comparison operators can be used to compare data types and will return a boolean value of `True` or `False`. The Python syntax for comparison operators is listed below.
#
# <br>
#
# <div>
# <img src="https://github.com/campbelle1/Introduction-to-Data-Science/blob/main/Week%201/comparison-operators.png?raw=true" width="600"/>
# </div>
#
# Note that the operator for equal is a double equal sign (`==`) and not `=`. Remember that a single equal sign is reserved for variable assignment.
#
# Just as shown before, you can compare numbers

# %%
n = 26 != 18
print(n)

# %% [markdown]
# ### Logical Operators
#
# Logical operators are also used in functions and conditional statements. They also output boolean values.
#
# <br>
#
# <div>
# <img src="https://github.com/campbelle1/Introduction-to-Data-Science/blob/main/Week%201/logical-operators.png?raw=true" width="600"/>
# </div>

# %% [markdown]
# When comparing variables with the logical operator `and`, both variables must equate to a `True` value for the overall boolean comparison to be `True`. If one value equates to `False`, then the entire comparison is `False`

# %%
q = 27
q < 30 and q > 15

# %%
q < 10 and q != 15

# %% [markdown]
# When comparing variables with the logical operator `or`, only one variable needs to equate to a `True` value for the overall boolean comparison to be `True`. If both are `False`, then the entire boolean comparison is `False`

# %%
q < 10 or q > 15

# %%
q < 10 or q > 65

# %% [markdown]
# The `not` logical operator simply negates the boolean value of a variable. People often use the `!=` comparison operator to do the same thing:

# %%
not 1 < 2

# %% [markdown]
# Below is a table of the outcomes of hypothetical logical comparisons with `and` and `or`:
#
# <br>
#
# <div>
# <img src="https://github.com/campbelle1/Introduction-to-Data-Science/blob/main/Week%201/comparison-table.png?raw=truee" width="600"/>
# </div>

# %% [markdown]
# ### Bitwise Operators
#
# In addition to logical operators, Python can use what are called *bitwise operators*. These operators are useful when we do selection of data from dataframes, which we will talk about in a future lesson.
#
# For now, just know that `&` is the bitwise operator for `and`; the `|` symbol is the bitwise operator for `or`.

# %% [markdown]
# ## Strings
#
# Strings are a series of alphanumeric and punctuation characters. We will spend a lot of time working with strings this summer since they are the main source of data used for NLP (Natural Language Processing), and all of your projects will have an NLP element.
#
# To make a string, place these characters inside a set of single, double, or triple quotations.

# %%
phrase = "Is it harder to toot, or to tutor two tooters to toot?"
print(phrase)

# %% [markdown]
# The number of characters in a string can be determined by using the `len()` function

# %%
len(phrase)

# %% [markdown]
# We can use multiplication and addition on Strings too. What do you think these will print?

# %%
print(2*phrase)
print(phrase+phrase)

# %% [markdown]
# We see that Python prints the sentence twice, but these sentences run into each other (i.e. there is no space in between).
#
# We have to specifically tell Python to add this space. We can do this by printing the string variables that we want as an expression by using the `+` operator and a space in quotation marks (" "). We call using the `+` operator with Strings *concatenation*.
#
# We can also do this by adding multiple arguments to the `print()` function, separated by a comma.

# %%
three = 3
print('My number is', three)

# %%
print(phrase, phrase)
print(phrase + " " + phrase)

# %% [markdown]
# Numerical data types can also be converted to strings by using the `str()` function.

# %%
five = str(5)
print(five)
five + five

# %% [markdown]
# Python also has what are called <u>*methods*</u>. A method is like a function in that it performs a task. However, methods are associated with an object, while a function may need an input for it to be used. We can invoke methods by calling for it on an object like so: `object.method_name()`.
#
#
# Let's use the `.count()` method on `phrase` to count how many times the word "toot" appears:

# %%
phrase.count('toot')

# %% [markdown]
# We can also break a string into pieces using the `.split()` method. The `.split()` method breaks a string anywwhere it finds a specified expression.
#
# For example, we can split up `phrase` by the spaces (" ") in it:

# %%
phrase.split(" ")

# %% [markdown]
# This creates a `list` of all the words in `phrases`. We'll learn more about lists later. For now, we can count the number of words by using the above code as an argument for the `len()` function.

# %%
len(phrase.split(" "))

# %% [markdown]
# Finally, we can replace words in a string variable by using the `.replace()` method. With this method, we can specify the expression we want to replace, followed by what we want to replace it with.

# %%
phrase.replace("harder", "easier")

# %% [markdown]
# Documentation for the `.count()`, `.replace()`, and `.split()` methods, as well as other string methods, can be found <a href="https://docs.python.org/3/library/stdtypes.html#textseq">here</a>.

# %% [markdown]
# ### Escape Sequences
#
# Escape sequences are string modifiers that allow for the use of certain characters that would otherwise be misinterpreted by Python. For example, because strings are created using quotes, the escape sequences `\'` and `\"` allow for the use of quotes as <u>part</u> of a string:

# %%
words = "My dad said, \"You\'re going to be okay.\" I looked at him and gave him a hug."
print(words)
# Out:
# My dad said, "You're going to be okay." I looked at him and gave him a hug.

# %% [markdown]
# Though, alternatively, you could just use different types of quotations like so:

# %%
words = 'My dad said, "You\'re going to be okay." I looked at him and gave him a hug.'
print(words)
# Out:
# My dad said, "You're going to be okay." I looked at him and gave him a hug.

# %% [markdown]
# Note: You still need to escape the apostrophe in You're as it has no matching end quote.

# %% [markdown]
# Other useful escape sequences include `\n` and `\t`. These allow for a new line and tab spacing to be added to a string, respectively.

# %%
sentences = 'This is the first sentence \nThis is the second sentence! \tThis is the third sentence?'
print(sentences)

# %% [markdown]
# We encourage you to spend time investigating and manipulating String data types to help you feel more comfortable with text data before arriving at UChicago this summer.
#
# ## Wrapping Up
#
# In this notebook, we got comfortable using Jupyter Notebooks and learned the basic data types used in Python. However, data scientists rarely work with a single string or integer object. In class, we will learn to work with collections of these data types.

# %% [markdown]
# ## ✏ <mark style="background-color: Thistle">Reflection</mark>
# In the following markdown cell, write about something you learned while working through this notebook.

# %% [markdown]
# Your answer here
