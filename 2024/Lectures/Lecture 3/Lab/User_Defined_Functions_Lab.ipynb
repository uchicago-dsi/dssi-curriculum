# %% [markdown]
# <center>
#
# # DSSI: Summer 2024
#
# ## User Defined Functions Lab
#
# #### Authored by: Bill Trok - University of Chicago
#
# <center>
# <img src="https://raw.githubusercontent.com/amandakube/Data118LectureImages/main/UChicago_DSI.png" alt="UC-DSI" width="300" height="100">
# </center>

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Exercise 1
#
# Define a function that takes two inputs x and y and returns the value x squared plus 5 times y (that is $x^2+5y$). The default value of y should be -1.
#
# Call this function bar.
#
# Test your function by calling bar(2,6) and bar(5)

# %%
# Your Code Here

# %% [markdown]
# ## Exercise 2
#
# Consider the dataframe below. Using a user defined function and an ``.apply()`` add a column called "Num Sentences" to the dataframe that counts that number of sentences in the "Description". You may assume that every sentence ends with a period.

# %%
text_df = pd.read_csv("important_info.csv")
text_df
# Out:
#                      Title Importance  \
# 0                     Frog      ★★★☆☆
# 1                    House      ★★★★☆
# 2                   Cheese      ★★★☆☆
# 3           Cheddar Cheese      ★★★★★
# 4  Fresh Prince of Bel-Air      ★★★★★
#
#                                          Description
# 0  A frog is any member of a diverse and largely ...
# 1  A house is a single-unit residential building....
# 2  Cheese is a dairy product produced in a range ...
# 3  Cheddar cheese (or simply cheddar) is a natura...
# 4  The Fresh Prince of Bel-Air is an American tel...

# %%
# Your code here.

# %% [markdown]
# ## Exercise 3
#
# The function ``integer_sum`` is supposed to take a number $n$ and return the sum of the numbers 1 through n. However, it's not working. Fix the issues.

# %%
def integer_sum(n):
  """Returns the sum of the integers 1-n"""

  for i in range(n):
    result = 0
    result +=i
  print(result)


integer_sum(5)
# Out:
# 4

# %%
# Check Your answer these should all return true
print(integer_sum(1) == 1)
print(integer_sum(100) == 5050)
print(integer_sum(1000)== 500*1001)

# %% [markdown]
# ## Exercise 4
#
# Recall that a palindrome is a word or phrase that is the same written backwards and forwards. For instance "ABBA" and "racecar" are both palindromes. Write a function that takes a string and returns a boolean. True if the string is a palindrome and false if it isn't a palindrome.
#
# HINT: If ``l`` is a list or string, then ``l[::-1]`` is the list in reverse order.
#
# This function should ignore case. For instance, it should return true if "Anna" is passed as it's parameter.

# %%
def is_palindrome(word):
    ...

# %%
print(is_palindrome("Anna"))
print(is_palindrome("Pizza"))
# Out:
# True
# False

# %% [markdown]
# ## Exercise 5
#
# Build a function that takes a string, and removes all punctuation, white space and other special characters other than alphanumeric characters (aka just letters A-Z,a-z and the digits 0-9).

# %%
def simplify_string(phrase):
    ...

# %% [markdown]
# ## Exercise 6
# Define a function that takes a list of words, and combines them into a single string seperated by spaces.

# %%
def combine(list_of_words):
    ...

# %% [markdown]
# ## Exercise 7 (Challenge)
#
# Build a function that takes in a sentence, or passage of text and returns the longest palindromic phrase contained within. Palindromic phrases should ignore spaces, punctuation and capitalization, but must cannot start or end in the middle of a word.
#
# For instance, the longest Palindrome in the sentence "This is a sentence" should be "a" and not "sas" or "isi". The longest Palindrome in "At the end of the day a Toyota's a Toyota." Is "a Toyota's a Toyota."
#
# HINT: Use your solutions to the previous exercises.

# %%
def find_palindrome(phrase):
    ...

# %%
#Test Cases all these should return true.
print(find_palindrome("Does this sentence contain a palindrome?") == "a")
print(find_palindrome("Was it a cat I saw or a dog?") == "Was it a cat I saw")
print(find_palindrome("At the end of the day a Toyota's a Toyota.") == "a Toyota's a Toyota.")
