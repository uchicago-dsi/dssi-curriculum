# %% [markdown]
# <center>
#
# # DSSI Summer Research Experience
# ## Monday Homework: Lists, Arrays, and DataFrames + Strings
#
# Please complete this notebook by filling in the cells provided. The solved homework should be uploaded to Gradescope on Canvas.
#
# <center>
# <img src="https://raw.githubusercontent.com/amandakube/Data118LectureImages/main/UChicago_DSI.png" alt="UC-DSI" width="300" height="100">
# </center>

# %% [markdown]
# #### Deadline:
#
# This assignment is due on **Monday at 11:30pm**.
#
# Directly sharing answers is not okay, but discussing problems with eachother is encouraged!

# %%
# Don't change this cell; just run it.
import numpy as np
import pandas as pd

# %% [markdown]
# # Strings and Lists
#
# Consider the list below:

# %%
my_words = ["My", "I", "This", 'a', "She", 7, """am""", 89, "is", 'sentence', 'cup', 'dog', 'cute', 'love', '.', '!' ]

# %% [markdown]
# **Question 1.** Extract and slice from the list `my_words` to create the sentence: "This is a sentence." You should assign it to the variable `sent`. You can use list methods or operations.

# %%
#Your code here (you may add more cells as needed)
sent = my_words[2] + " " + my_words[8] + " " + my_words[3] + " " + my_words[9] + my_words[14]
sent
# Out:
# 'This is a sentence.'

# %% [markdown]
# **Question 2.** Create two sentences assigned to `sent_low` and `sent_up` which contain the sentence from `sent` with all lowercase and all uppercase letters respectively.
#
# Hint: This [link](https://www.w3schools.com/python/python_ref_string.asp) will be helpful.

# %%
#Your code here (you may add more cells as needed)
sent_low = sent.lower()
sent_up = sent.upper()

# %% [markdown]
# **Question 3** How many words and characters are in the string below? Assign the counts to the variables `words` and `characters`. Do not just count yourself, use python. Refer to the link in the hint above for methods that can be helpful.
#
# Hint1: You may want to first replace the \n with spaces.
#
# Hint2: Lists may be useful here.

# %%
long_string = '''Two roads diverged in a yellow wood,
And sorry I could not travel both
And be one traveler, long I stood
And looked down one as far as I could
To where it bent in the undergrowth;
Then took the other, as just as fair,
And having perhaps the better claim,
Because it was grassy and wanted wear;
Though as for that the passing there
Had worn them really about the same,
And both that morning equally lay
In leaves no step had trodden black.
Oh, I kept the first for another day!
Yet knowing how way leads on to way,
I doubted if I should ever come back.
I shall be telling this with a sigh
Somewhere ages and ages hence:
Two roads diverged in a wood, and I—
I took the one less traveled by,
And that has made all the difference.'''
long_string
# Out:
# 'Two roads diverged in a yellow wood,\nAnd sorry I could not travel both\nAnd be one traveler, long I stood\nAnd looked down one as far as I could\nTo where it bent in the undergrowth;\nThen took the other, as just as fair,\nAnd having perhaps the better claim,\nBecause it was grassy and wanted wear;\nThough as for that the passing there\nHad worn them really about the same,\nAnd both that morning equally lay\nIn leaves no step had trodden black.\nOh, I kept the first for another day!\nYet knowing how way leads on to way,\nI doubted if I should ever come back.\nI shall be telling this with a sigh\nSomewhere ages and ages hence:\nTwo roads diverged in a wood, and I—\nI took the one less traveled by,\nAnd that has made all the difference.'

# %%
#Your code here (you may add more cells as needed)
characters = long_string.len()
long_string = long_string.replace("\n"," ")
words = len(long_string.split(" "))

# %% [markdown]
# **Question 4.** Use the *replace* method for strings to change the string *'machine learning'* into the string *'learning machine'*. You must do everything into one line of code and you can only replace one full word with a different full word. Save the string in the variable `mllm`. An example of using *replace* twice in one line of code is below. [Note: the output should be a string of the same length as the one you started with; no extra spaces etc. and should be all lowercase; just like the string you start with]

# %%
# this cell illustrates the use of .replace
'Today is a good day.'.replace('.','!')

# %%
# this cell illustrates the use of .replace twice
'on campus'.replace('on','happy').replace('campus','place')

# %%
#Your code here (you may add more cells as needed)
mllm = "machine learning".replace("machine","temp").replace("learning","machine").replace("temp","learning")

# %% [markdown]
# # Puzzles with Arrays

# %% [markdown]
# **Question 5.**
#
# **a.** Create an array containing every 6th number between 7 and 700 inclusive (Hint: please do not type all of these numbers, use a function).
#
# **b.** Find the remainder after dividing each number by 7 (Hint: what operator can you use here).
#
# **c.** Then, take the average of the resulting numbers and save it in the variable `array_math`.

# %%
#Your code here (you may add more cells as needed)
array_math = np.mean(np.arange(7,701,6) % 7)

# %% [markdown]
# **Question 6.**

# %% [markdown]
# **a.** Create an array called `four` that includes all integers from 4 to 120 (inclusive) in intervals of 4
#
# **b.** Create an array called `five` which alters `four` to be a 5x6 array. Print the result.
#
# **c.** Write code to select the highlighted numbers in the image below:
#
# <br>
#
# <div>
# <img src="https://raw.githubusercontent.com/campbelle1/Introduction-to-Data-Science/main/Week%202/Array-exercise2.png"/>
# </div>
#
# The highlighted numbers in the leftmost panel of the image should be save in an array called `left`. The highlighted numbers in the middle panel of the image should be save in an array called `mid`. The highlighted numbers in the rightmost panel of the image should be save in an array called `right`.

# %%
#Your code here (you may add more cells as needed)
four = np.arange(4,121,4)
five = four.reshape(5,6)
five
# Out:
# array([[  4,   8,  12,  16,  20,  24],
#        [ 28,  32,  36,  40,  44,  48],
#        [ 52,  56,  60,  64,  68,  72],
#        [ 76,  80,  84,  88,  92,  96],
#        [100, 104, 108, 112, 116, 120]])

# %%
right = five[0::2,]
left = five[0::2, 0::2]
mid = five[:, 1::2]
# Out:
# array([[  8,  16,  24],
#        [ 32,  40,  48],
#        [ 56,  64,  72],
#        [ 80,  88,  96],
#        [104, 112, 120]])

# %% [markdown]
# ## A Cognitive Study with DataFrames

# %% [markdown]
# A neuroscience research firm is testing out a new game that exercises memory, reasoning, and other cognitive functions. They conducted a pilot study with 1000 subjects that measures the time of completion of the game, difficulty level, and number of incorrect questions for a game consisting of 20 exercises. For each person that participated in the study demographic information was recorded, including age and gender.
#
# Load in the data for this study from `cognitive_data.csv` which can be found with this assignment on Canvas. Assign this to a dataframe named `cog_data`.

# %%
#Your code here (you may add more cells as needed)
cog_data = pd.read_csv("cognitive_data.csv")

# %% [markdown]
# **Question 7.** Each study participant played the game at a specific difficulty level where Level 1 is easy, Level 2 is medium, and Level 3 is hard. Create a new dataframe `cog_data_str` that is a copy of `cog_data`. Then change the values in the `Difficulty` column of `cog_data_str` so that the levels are represented categorically (aka as a string) instead of numerically.

# %%
#Your code here (you may add more cells as needed)
cog_data_str = cog_data.copy()
cog_data_str['Difficulty'] = cog_data_str['Difficulty'].astype(str)
cog_data_str
# Out:
#     Gender  Age Difficulty  Completion Time (sec)  Number Incorrect
# 0    Woman   21          1                    193                 2
# 1      Man   43          1                    154                 6
# 2      Man   38          3                    298                 6
# 3      Man   37          3                    528                10
# 4    Woman   27          2                    217                 8
# ..     ...  ...        ...                    ...               ...
# 995  Woman   28          3                    475                 6
# 996    Man   23          1                    159                 1
# 997    Man   53          1                    142                 5
# 998    Man   24          2                    229                 1
# 999  Woman   48          3                    343                 3
#
# [1000 rows x 5 columns]

# %% [markdown]
# **Question 8.** Create another new dataframe `cog_data_incor` that is a copy of `cog_data_str`. Calculate the percentage of incorrect answers for each participant and add this information to the new dataframe in a new column called `Incorrect %`.

# %%
#Your code here (you may add more cells as needed)
cog_data_incor = cog_data.copy()
cog_data_incor['Incorrect %'] = cog_data_incor['Number Incorrect'] / 20 * 100

# %% [markdown]
# **Question 9.** Construct a dataframe named `cog_data_avg` that displays the average completion time for each difficulty level for each recorded gender.

# %%
#Your code here (you may add more cells as needed)
cog_data_avg = cog_data.groupby(["Difficulty","Gender"]).mean()[['Completion Time (sec)']]
cog_data_avg
# Out:
#                        Completion Time (sec)
# Difficulty Gender
# 1          Man                    151.934641
#            Non-binary             167.117647
#            Other                  169.571429
#            Woman                  153.593939
# 2          Man                    313.261438
#            Non-binary             320.526316
#            Other                  339.166667
#            Woman                  303.486842
# 3          Man                    453.753521
#            Non-binary             455.000000
#            Other                  449.000000
#            Woman                  438.030864

# %% [markdown]
# **Question 10.** Which gender had the lowest average completion time for each difficulty level? Assign your answers to the variables `easy`, `medium`, and `hard`. Do this using code, not by visual inspection.
#
# Hint: This may take more than one line, and you may want to look unto the function `argmin`.

# %%
#Your code here (you may add more cells as needed)
df = cog_data_avg.reset_index()
easyid = df.loc[df["Difficulty"] == 1, "Completion Time (sec)"].argmin()
easy = df.loc[df["Difficulty"] == 1,"Gender"].iloc[easyid]
easy
# Out:
# 'Man'

# %%
medid = df.loc[df["Difficulty"] == 2, "Completion Time (sec)"].argmin()
medium = df.loc[df["Difficulty"] == 2,"Gender"].iloc[medid]
medium
# Out:
# 'Woman'

# %%
hardid = df.loc[df["Difficulty"] == 3, "Completion Time (sec)"].argmin()
hard = df.loc[df["Difficulty"] == 3,"Gender"].iloc[hardid]
hard
